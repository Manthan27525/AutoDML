# %%
from autodml import Autodml
import pandas as pd

# %%
df=pd.read_csv(r"D:\Downloads\temp\olympics.csv")
df.head()
# Out:
#   athlete_id       athlete_name  gender  age date_of_birth nationality  \
# 0  ATH-00001      Svetlana Jung  Female   19    2005-12-04         AUT
# 1  ATH-00002      Mary Yamamoto  Female   37    1987-07-11         MEX
# 2  ATH-00003      Oksana Volkov  Female   37    1987-02-02         BUL
# 3  ATH-00004         Rui Suzuki    Male   32    1992-12-08         HKG
# 4  ATH-00005  Natalya Grigoryan  Female   27    1997-11-15         SWE
#
#   country_name           sport             event games_type  ...  \
# 0      Austria          Rowing            Four W     Summer  ...
# 1       Mexico     Ski Jumping  Normal Hill Team     Winter  ...
# 2     Bulgaria  Figure Skating   Women's Singles     Winter  ...
# 3    Hong Kong       Triathlon   Men's Triathlon     Summer  ...
# 4       Sweden       Triathlon   Men's Triathlon     Summer  ...
#
#    bronze_medals country_total_gold country_total_medals  \
# 0              1                 59                  196
# ...

# %%
model=Autodml(data=df,target="medal")
model.train()
# Out:
# 2026-03-31 15:28:26,963 - autodml.pipeline - INFO - Running AUTODML Pipeline.
# 2026-03-31 15:28:26,966 - autodml.data_analysis - INFO - Generating data analysis report
# 2026-03-31 15:28:26,968 - autodml.data_analysis - INFO - Analyzing dataset overview...
# 2026-03-31 15:28:27,098 - autodml.data_analysis - INFO - Analyzing column statistics...
# 2026-03-31 15:28:27,172 - autodml.data_analysis - INFO - Analyzing target variable...
# 2026-03-31 15:28:27,174 - autodml.preprocessing - INFO - Detecting Problem Type.
# 2026-03-31 15:28:27,179 - autodml.data_analysis - INFO - Analyzing numeric features...
# 2026-03-31 15:28:27,180 - autodml.preprocessing - INFO - Starting Feature Types Detection.
# D:\Project\AutoDML\autodml\preprocessing.py:257: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(sample, errors="coerce")
# ...
