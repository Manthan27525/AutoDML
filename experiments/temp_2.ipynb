# %%
import os
path="../temp/Salary_dataset.csv"
os.path.splitext(path)[1]
# Out:
# '.csv'

# %%
import pandas as pd
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.empty
# Out:
# False

# %%
df.columns.duplicated()
# Out:
# array([False, False, False])

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
d1=df.isna().sum()

# %%
df["Salary"].count()
# Out:
# np.int64(30)

# %%
df['Salary'].isna().sum()
# Out:
# np.int64(0)
