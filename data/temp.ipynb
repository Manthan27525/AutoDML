# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open("model/model.pkl","rb") as f:
    model=pickle.load(f)

# %%
inp=np.array([[5,80,1,7,0]])

# %%
model.predict(inp)
# Out:
# array([75.65274883])
